# %%
i = "Belajar Python itu menyenangkan"

print(i*10)
# Out:
# Belajar Python itu menyenangkanBelajar Python itu menyenangkanBelajar Python itu menyenangkanBelajar Python itu menyenangkanBelajar Python itu menyenangkanBelajar Python itu menyenangkanBelajar Python itu menyenangkanBelajar Python itu menyenangkanBelajar Python itu menyenangkanBelajar Python itu menyenangkan

# %%
def cetak_apapun10x(teks):
  for i in range(10):
    i = print(teks)

cetak_apapun10x('Belajar Pemograman Dapat Mengasah Logika Berpikir')
# Out:
# Belajar Pemograman Dapat Mengasah Logika Berpikir
# Belajar Pemograman Dapat Mengasah Logika Berpikir
# Belajar Pemograman Dapat Mengasah Logika Berpikir
# Belajar Pemograman Dapat Mengasah Logika Berpikir
# Belajar Pemograman Dapat Mengasah Logika Berpikir
# Belajar Pemograman Dapat Mengasah Logika Berpikir
# Belajar Pemograman Dapat Mengasah Logika Berpikir
# Belajar Pemograman Dapat Mengasah Logika Berpikir
# Belajar Pemograman Dapat Mengasah Logika Berpikir
# Belajar Pemograman Dapat Mengasah Logika Berpikir
