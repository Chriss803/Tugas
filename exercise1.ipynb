# %%
#===Soal No 1===#
def cetak_10x():
  cetak = 10
  for i in range(cetak):
    print(f"Belajar Python itu menyenangkan")

cetak_10x()
# Out:
# Belajar Python itu menyenangkan
# Belajar Python itu menyenangkan
# Belajar Python itu menyenangkan
# Belajar Python itu menyenangkan
# Belajar Python itu menyenangkan
# Belajar Python itu menyenangkan
# Belajar Python itu menyenangkan
# Belajar Python itu menyenangkan
# Belajar Python itu menyenangkan
# Belajar Python itu menyenangkan

# %%
#===Soal No 2===#
def cetak_apapun10x(teks):
  for i in range(10):
    i = print(teks)
    # print (type ('i'))

cetak_apapun10x('Belajar Pemprogramman Dapat Mengasah Logika Berfikir')
# Out:
# Belajar Pemprogramman Dapat Mengasah Logika Berfikir
# Belajar Pemprogramman Dapat Mengasah Logika Berfikir
# Belajar Pemprogramman Dapat Mengasah Logika Berfikir
# Belajar Pemprogramman Dapat Mengasah Logika Berfikir
# Belajar Pemprogramman Dapat Mengasah Logika Berfikir
# Belajar Pemprogramman Dapat Mengasah Logika Berfikir
# Belajar Pemprogramman Dapat Mengasah Logika Berfikir
# Belajar Pemprogramman Dapat Mengasah Logika Berfikir
# Belajar Pemprogramman Dapat Mengasah Logika Berfikir
# Belajar Pemprogramman Dapat Mengasah Logika Berfikir

# %%
#===Soal No 3===#
def cetak_apapun_10x_dengan_input():
  user = input ('Silahkan Input: ')

  if user == 'berhenti':
    print('Terima Kasih Sudah Menggunakan Program Kami!')
  else: 
    for x in range(10):
        print('Cara Terbaik Belajar Pemprogramman Adalah Mempelajari Teori Diiringi Praktek Dan Banyak Latihan')

cetak_apapun_10x_dengan_input()
# Out:
# Silahkan Input: a
# Cara Terbaik Belajar Pemprogramman Adalah Mempelajari Teori Diiringi Praktek Dan Banyak Latihan
# Cara Terbaik Belajar Pemprogramman Adalah Mempelajari Teori Diiringi Praktek Dan Banyak Latihan
# Cara Terbaik Belajar Pemprogramman Adalah Mempelajari Teori Diiringi Praktek Dan Banyak Latihan
# Cara Terbaik Belajar Pemprogramman Adalah Mempelajari Teori Diiringi Praktek Dan Banyak Latihan
# Cara Terbaik Belajar Pemprogramman Adalah Mempelajari Teori Diiringi Praktek Dan Banyak Latihan
# Cara Terbaik Belajar Pemprogramman Adalah Mempelajari Teori Diiringi Praktek Dan Banyak Latihan
# Cara Terbaik Belajar Pemprogramman Adalah Mempelajari Teori Diiringi Praktek Dan Banyak Latihan
# Cara Terbaik Belajar Pemprogramman Adalah Mempelajari Teori Diiringi Praktek Dan Banyak Latihan
# Cara Terbaik Belajar Pemprogramman Adalah Mempelajari Teori Diiringi Praktek Dan Banyak Latihan
# Cara Terbaik Belajar Pemprogramman Adalah Mempelajari Teori Diiringi Praktek Dan Banyak Latihan

# %%
#===Soal No 4===#
def cetak_apapun_10x_dengan_default(teks = 'Selamat Belajar Python, jangan Lupa Perbanyak Latihan Yaa'):
  for i in range(10):
    i = print(teks)

cetak_apapun_10x_dengan_default()
# cetak_apapun_10x_dengan_default('Oh Senangnya, Aku Senang Sekali :D')

# %%
#===Soal No 5===#
def hitung_luas_persegi(sisi = float()):
  luas = (sisi * sisi )
  print("Luas Persegi adalah: ",luas)
  # print (type(sisi))

# hitung_luas_persegi(9.23)
# hitung_luas_persegi(12.0)
# hitung_luas_persegi(13)
hitung_luas_persegi(20)
# Out:
# Luas Persegi adalah:  400

# %%
#===Soal No 6===#
tanpa_kembalian = hitung_luas_persegi(400)
type(tanpa_kembalian)
# Out:
# Luas Persegi adalah:  160000
# NoneType

# %%
#===Soal No 7===#
def hitung_luas_persegi_panjang(panjang = float(), lebar = float()):
  luas = panjang*lebar
  return luas

# hitung_luas_persegi_panjang(5,8)
hitung_luas_persegi_panjang(5,8)
# Out:
# 40

# %%
#===Soal No 8===#
dengan_kembalian = hitung_luas_persegi_panjang()
type(dengan_kembalian)
# Out:
# float
