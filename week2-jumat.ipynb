# %%
def my_function(num1,num2=5):
  output = num1 + num2
  return output

# %%
my_function(6)
# Out:
# 11

# %%
my_function(5,9)
# Out:
# 14

# %%
x= 5
y = 2
def my_function(num1,num2):
  print(f"value of x is {x}")
  print(f"value of y is {y}")
  num3 = num1 + num2 + x
  return num3

# %%
my_function(4,4)
# Out:
# value of x is 5
# value of y is 2
# 13

# %%
my_function(5,2)
# Out:
# value of x is 5
# value of y is 2
# 12
